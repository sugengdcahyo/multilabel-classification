# %%
# !pip install "elasticsearch<8.0.0"
# Out:
# Requirement already satisfied: elasticsearch<8.0.0 in /usr/local/lib/python3.11/dist-packages (7.17.12)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from elasticsearch<8.0.0) (1.26.20)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from elasticsearch<8.0.0) (2025.1.31)

# %%
from elasticsearch import Elasticsearch

# Konfigurasi koneksi ke Elasticsearch
ELASTICSEARCH_HOST = "http://es.robota.datains.id:80"  # Ganti dengan host Elasticsearch Anda
INDEX_NAME = "hotel_reviews"  # Ganti dengan nama indeks yang ingin diambil datanya

# Inisialisasi koneksi ke Elasticsearch
es = Elasticsearch([ELASTICSEARCH_HOST])


def get_large_data_from_elasticsearch(index, size=10000):
    """
    Mengambil data hingga 10.000 dokumen dari Elasticsearch dengan metode search_after.

    :param index: Nama indeks Elasticsearch.
    :param size: Jumlah maksimum data yang ingin diambil.
    :return: List hasil pencarian.
    """
    query = {
        "query": {
            "bool": {
                "must_not": [
                    {"match": { "sentiment_general": "Negative"}},
                ],
                "must": [
                    {"exists": {"field": "review.message"}},
                    {"exists": {"field": "sentiment"}},
                    {
                        "range": {
                            "review.date": {
                                "gte": "2022-01-22",
                                "lte": "now"
                            }
                        }
                    }
                ]
            }
        },
        "sort": [
            {"review.date": {"order": "desc"}},
            {"_id": "asc"}  # Tambahkan _id untuk search_after
        ],
        "_source": ["source", "review", "sentiment", "sentiment_general"],
        "size": 1000  # Ambil data dalam batch 1000 per iterasi
    }

    results = []
    last_hit = None

    while len(results) < size:
        if last_hit:
            query["search_after"] = last_hit

        response = es.search(index=index, body=query)
        hits = response.get("hits", {}).get("hits", [])

        if not hits:
            break  # Jika tidak ada data lagi, berhenti

        results.extend(hits)

        # Set `search_after` berdasarkan dokumen terakhir
        last_hit = hits[-1]["sort"]

        # Jika sudah mencapai 10.000 data, berhenti
        if len(results) >= size:
            break

    return results[:size]  # Pastikan hanya 10.000 data yang dikembalikan


def get_large_negative_data_from_elasticsearch(index, size=10000):
    """
    Mengambil data hingga 10.000 dokumen dari Elasticsearch dengan metode search_after.

    :param index: Nama indeks Elasticsearch.
    :param size: Jumlah maksimum data yang ingin diambil.
    :return: List hasil pencarian.
    """
    query = {
        "query": {
            "bool": {
                "must": [
                    {"match": { "sentiment_general": "Negative"}},
                    {"exists": {"field": "review.message"}},
                    {"exists": {"field": "sentiment"}},
                    {
                        "range": {
                            "review.date": {
                                "gte": "2022-01-22",
                                "lte": "now"
                            }
                        }
                    }
                ]
            }
        },
        "sort": [
            {"review.date": {"order": "desc"}},
            {"_id": "asc"}  # Tambahkan _id untuk search_after
        ],
        "_source": ["source", "review", "sentiment", "sentiment_general"],
        "size": 1000  # Ambil data dalam batch 1000 per iterasi
    }

    results = []
    last_hit = None

    while len(results) < size:
        if last_hit:
            query["search_after"] = last_hit

        response = es.search(index=index, body=query)
        hits = response.get("hits", {}).get("hits", [])

        if not hits:
            break  # Jika tidak ada data lagi, berhenti

        results.extend(hits)

        # Set `search_after` berdasarkan dokumen terakhir
        last_hit = hits[-1]["sort"]

        # Jika sudah mencapai 10.000 data, berhenti
        if len(results) >= size:
            break

    return results[:size]  # Pastikan hanya 10.000 data yang dikembalikan

# %%
import json
import pandas as pd

# Fungsi untuk mengonversi JSON Elasticsearch ke CSV
def convert_json_to_df(data):
    """
    Mengonversi file JSON hasil Elasticsearch ke CSV dengan hanya mengambil
    review.message, language.language, sentiment.*, dan sentiment_general.

    :param json_file: Path file JSON input.
    :param csv_file: Path file CSV output.
    """
    # Pastikan data dalam format Elasticsearch (_source)
    records = []
    for record in data:  # Ambil dari _source
        source = record["_source"]
        row = {
            "review_message": source.get("review", {}).get("message", ""),
            "source": source.get("source", None),
            "language": source.get("review", {}).get("language", ""),
            "sentiment_general": source.get("sentiment_general", ""),
            "rating": source.get("review", {}).get("rating_normalization", {}).get("normal", None)
        }

        # Ambil semua sentiment.*
        for key, value in source.get("sentiment", {}).items():
            row[f"sentiment_{key}"] = value

        records.append(row)

    # Konversi ke DataFrame
    df = pd.DataFrame(records)
    return df

# %%
# Query untuk mengambil semua data
results_no_negative = get_large_data_from_elasticsearch(INDEX_NAME, size=15000)
results_negative = get_large_negative_data_from_elasticsearch(INDEX_NAME, size=5000)
# Out:
# <ipython-input-2-3fdb6a487ee9>:54: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   response = es.search(index=index, body=query)
# <ipython-input-2-3fdb6a487ee9>:113: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   response = es.search(index=index, body=query)

# %%
# Contoh penggunaan

df_no_negative = convert_json_to_df(results_no_negative)
df_negative = convert_json_to_df(results_negative)

df = pd.concat([df_no_negative, df_negative], ignore_index=True)

# %%
df_no_negative
# Out:
#                                           review_message       source  \
# 0      Kamar bersih, ac dingin, air panas tdk konsist...       google
# 1      "I always stay at Horison Sukabumi Hotel when ...  tripadvisor
# 2      Bagus sekali, pengalaman pertama kali menginap...  tripadvisor
# 3      Kamarnya nya sangat bersih dan pelayanan nya j...  tripadvisor
# 4      Sudah langganan disini,,terimakasih agoda akan...        agoda
# ...                                                  ...          ...
# 14995                                         Good place       google
# 14996                                    resto and hotel       google
# 14997                                         Good place       google
# 14998                                  View from the top       google
# 14999                                           Standard       google
#
#          language sentiment_general  rating sentiment_meal  \
# 0      Indonesian                       8.0       negative
# 1         English                      10.0        neutral
# 2      Indonesian                      10.0
# 3      Indonesian                      10.0       positive
# 4      Indonesian           Neutral    10.0
# ...           ...               ...     ...            ...
# 14995     English           Neutral    10.0        neutral
# 14996     English           Neutral    10.0        neutral
# 14997     English           Neutral    10.0        neutral
# 14998     English           Neutral    10.0        neutral
# 14999  Indonesian           Neutral    10.0
#
#       sentiment_surrounding sentiment_service sentiment_location  \
# 0
# 1                  positive           neutral            neutral
# 2
# 3                                    positive
# 4
# ...                     ...               ...                ...
# 14995              positive           neutral            neutral
# 14996              positive           neutral            neutral
# 14997              positive           neutral            neutral
# 14998               neutral           neutral            neutral
# 14999
#
#       sentiment_staff sentiment_facility sentiment_value sentiment_room  \
# 0                               negative                       negative
# 1             neutral            neutral         neutral        neutral
# 2
# 3            positive
# 4
# ...               ...                ...             ...            ...
# 14995         neutral            neutral         neutral        neutral
# 14996         neutral            neutral         neutral        neutral
# 14997         neutral            neutral         neutral        neutral
# 14998         neutral            neutral         neutral        neutral
# 14999
#
#       sentiment_quality
# 0
# 1               neutral
# 2
# 3
# 4
# ...                 ...
# 14995           neutral
# 14996           neutral
# 14997           neutral
# 14998           neutral
# 14999
#
# [15000 rows x 14 columns]

# %%
df
# Out:
#                                           review_message       source  \
# 0      Kamar bersih, ac dingin, air panas tdk konsist...       google
# 1      "I always stay at Horison Sukabumi Hotel when ...  tripadvisor
# 2      Bagus sekali, pengalaman pertama kali menginap...  tripadvisor
# 3      Kamarnya nya sangat bersih dan pelayanan nya j...  tripadvisor
# 4      Sudah langganan disini,,terimakasih agoda akan...        agoda
# ...                                                  ...          ...
# 19995        ac tidak dingin, kasur jeblos, tembok kotor        tiket
# 19996  Breakfast ga Buffett. ..untuk harga 800rb an🤭😂...  tripadvisor
# 19997                                                .        booking
# 19998  I can understand that the pandemic has a big i...  tripadvisor
# 19999  Kamar Kotor, Jamuran, Sarang laba-laba dan sar...  tripadvisor
#
#          language sentiment_general  rating sentiment_meal  \
# 0      Indonesian                       8.0       negative
# 1         English                      10.0        neutral
# 2      Indonesian                      10.0
# 3      Indonesian                      10.0       positive
# 4      Indonesian           Neutral    10.0
# ...           ...               ...     ...            ...
# 19995  Indonesian          Negative     4.8
# 19996  Indonesian          Negative     2.0
# 19997     unknown          Negative     4.0
# 19998     English          Negative     2.0        neutral
# 19999  Indonesian          Negative     2.0       negative
#
#       sentiment_surrounding sentiment_service sentiment_location  \
# 0
# 1                  positive           neutral            neutral
# 2
# 3                                    positive
# 4
# ...                     ...               ...                ...
# 19995
# 19996
# 19997
# 19998              negative          negative            neutral
# 19999
#
#       sentiment_staff sentiment_facility sentiment_value sentiment_room  \
# 0                               negative                       negative
# 1             neutral            neutral         neutral        neutral
# 2
# 3            positive
# 4
# ...               ...                ...             ...            ...
# 19995                           negative                       negative
# 19996                           negative        negative       negative
# 19997
# 19998         neutral           negative         neutral       negative
# 19999                                                          negative
#
#       sentiment_quality
# 0
# 1               neutral
# 2
# 3
# 4
# ...                 ...
# 19995          negative
# 19996
# 19997
# 19998           neutral
# 19999          negative
#
# [20000 rows x 14 columns]

# %%
import pandas as pd
import numpy as np

# Mengganti semua nilai "" menjadi NaN
df.replace("", np.nan, inplace=True)

# Menampilkan jumlah nilai NaN setelah pembersihan
print(df.isna().sum())
# Out:
# review_message             35
# source                      0
# language                    0
# sentiment_general          38
# rating                      0
# sentiment_meal           6932
# sentiment_surrounding    8919
# sentiment_service        6229
# sentiment_location       8302
# sentiment_staff          6286
# sentiment_facility       7320
# sentiment_value          9112
# sentiment_room           5950
# sentiment_quality        6149
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   review_message         19965 non-null  object
#  1   source                 20000 non-null  object
#  2   language               20000 non-null  object
#  3   sentiment_general      19962 non-null  object
#  4   rating                 20000 non-null  float64
#  5   sentiment_meal         13068 non-null  object
#  6   sentiment_surrounding  11081 non-null  object
#  7   sentiment_service      13771 non-null  object
#  8   sentiment_location     11698 non-null  object
#  9   sentiment_staff        13714 non-null  object
#  10  sentiment_facility     12680 non-null  object
#  11  sentiment_value        10888 non-null  object
#  12  sentiment_room         14050 non-null  object
#  13  sentiment_quality      13851 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 2.1+ MB

# %%
df.isnull().sum()
# Out:
# review_message             35
# source                      0
# language                    0
# sentiment_general          38
# rating                      0
# sentiment_meal           6932
# sentiment_surrounding    8919
# sentiment_service        6229
# sentiment_location       8302
# sentiment_staff          6286
# sentiment_facility       7320
# sentiment_value          9112
# sentiment_room           5950
# sentiment_quality        6149
# dtype: int64

# %%
df = df.dropna(subset=["review_message"])

# %%
df.isnull().sum()
# Out:
# review_message              0
# source                      0
# language                    0
# sentiment_general          38
# rating                      0
# sentiment_meal           6905
# sentiment_surrounding    8892
# sentiment_service        6202
# sentiment_location       8275
# sentiment_staff          6263
# sentiment_facility       7293
# sentiment_value          9085
# sentiment_room           5924
# sentiment_quality        6124
# dtype: int64

# %%
df[df["sentiment_general"].isnull()]
# Out:
#                                           review_message       source  \
# 0      Kamar bersih, ac dingin, air panas tdk konsist...       google
# 1      "I always stay at Horison Sukabumi Hotel when ...  tripadvisor
# 2      Bagus sekali, pengalaman pertama kali menginap...  tripadvisor
# 3      Kamarnya nya sangat bersih dan pelayanan nya j...  tripadvisor
# 5      pelayanan Iftarnya baik dengan mbak Belinda, d...  tripadvisor
# 11     Hotel yang sangat rekomendedd dengan pemandang...  tripadvisor
# 12     saya menginapp di horison ultima entropp kebet...  tripadvisor
# 26     Nyaman, pelayanan bagus, makanan utama enak tp...  tripadvisor
# 45     Semua staff hotel ramah&helpfull untuk tempat ...       google
# 55     Saya mau menyampaikan bbrp complain :\n\n1. Sa...       google
# 9755   The room is very nice and clean. It was a plea...    traveloka
# 9818   The staff are all very friendly. The room is q...    traveloka
# 10111  Good attitude service from Mr. Surya and Ms. A...    traveloka
# 10280  The room is quite large and can view the city,...    traveloka
# 10346  It was very pleasant to stay here, 2 days felt...    traveloka
# 10757  Friendly and helpful hotel staff. Strategic lo...    traveloka
# 11413  nice room, spacious size, good service, check-...    traveloka
# 11572  The staff is very friendly, the room is very c...    traveloka
# 11574  Very strategic location near Tugu and Maliobor...    traveloka
# 11648  Good service and good room. The location is ve...    traveloka
# 11802  The hotel staff is friendly, the room is ready...    traveloka
# 11904     Cool tree, come back again, highly recommended    traveloka
# 11972  The rooms are comfortable, spacious and clean,...    traveloka
# 12026  Very comfortable hotel, strategic location 200...    traveloka
# 12079  Recommended Hotel, everything is good, breakfa...    traveloka
# 12126        the best is that all the staff are friendly    traveloka
# 12136  The hotel staff were all very friendly, the ro...    traveloka
# 12153  First time staying here, very impressive. Clea...    traveloka
# 12238  I don't regret it at all. Next time I go to Jo...    traveloka
# 12246  The staff was very friendly when checking in a...    traveloka
# 12303  Recommended hotel for families, anywhere, clos...    traveloka
# 12589  The room is spacious, the room is clean. The s...    traveloka
# 12655  Nice and cool, the position is not far from Ma...    traveloka
# 12777  Very impressive stay here hotel and the room i...    traveloka
# 12872     anyway, if you go to jogja, you must stay here    traveloka
# 13043  The check-in/check-out process is fast and you...    traveloka
# 13245  The room is quite big, the bathroom is also qu...    traveloka
# 13565  Good location. Good price. Friendly staff. Goo...    traveloka
#
#          language sentiment_general  rating sentiment_meal  \
# 0      Indonesian               NaN     8.0       negative
# 1         English               NaN    10.0        neutral
# 2      Indonesian               NaN    10.0            NaN
# 3      Indonesian               NaN    10.0       positive
# 5      Indonesian               NaN    10.0       positive
# 11     Indonesian               NaN    10.0            NaN
# 12     Indonesian               NaN    10.0            NaN
# 26     Indonesian               NaN     8.0       positive
# 45     Indonesian               NaN    10.0            NaN
# 55     Indonesian               NaN     2.0            NaN
# 9755      English               NaN     9.4        neutral
# 9818      English               NaN    10.0       positive
# 10111     English               NaN    10.0        neutral
# 10280     English               NaN     9.4       positive
# 10346     English               NaN    10.0       positive
# 10757     English               NaN     9.4        neutral
# 11413     English               NaN    10.0       positive
# 11572     English               NaN     9.7        neutral
# 11574     English               NaN     9.7        neutral
# 11648     English               NaN    10.0        neutral
# 11802     English               NaN    10.0       positive
# 11904     English               NaN    10.0        neutral
# 11972     English               NaN    10.0        neutral
# 12026     English               NaN    10.0       positive
# 12079     English               NaN     9.4       positive
# 12126     English               NaN    10.0        neutral
# 12136     English               NaN    10.0       positive
# 12153     English               NaN    10.0       positive
# 12238     English               NaN    10.0        neutral
# 12246     English               NaN    10.0        neutral
# 12303     English               NaN    10.0       positive
# 12589     English               NaN    10.0       positive
# 12655     English               NaN    10.0        neutral
# 12777     English               NaN    10.0        neutral
# 12872     English               NaN    10.0        neutral
# 13043     English               NaN     9.1        neutral
# 13245     English               NaN    10.0       positive
# 13565     English               NaN    10.0       positive
#
#       sentiment_surrounding sentiment_service sentiment_location  \
# 0                       NaN               NaN                NaN
# 1                  positive           neutral            neutral
# 2                       NaN               NaN                NaN
# 3                       NaN          positive                NaN
# 5                       NaN               NaN                NaN
# 11                      NaN               NaN                NaN
# 12                      NaN          positive                NaN
# 26                 positive          positive           positive
# 45                      NaN               NaN                NaN
# 55                      NaN               NaN                NaN
# 9755               positive           neutral            neutral
# 9818               positive           neutral           positive
# 10111               neutral          positive            neutral
# 10280              positive          positive           positive
# 10346              positive          positive            neutral
# 10757              positive          positive           positive
# 11413               neutral          positive            neutral
# 11572              positive          positive            neutral
# 11574              positive          positive           positive
# 11648               neutral          positive           positive
# 11802               neutral          positive            neutral
# 11904              positive           neutral            neutral
# 11972              positive          positive           positive
# 12026              positive           neutral           positive
# 12079              positive           neutral            neutral
# 12126               neutral          positive            neutral
# 12136              positive           neutral            neutral
# 12153               neutral          positive            neutral
# 12238              positive           neutral            neutral
# 12246               neutral          positive            neutral
# 12303              positive          positive           positive
# 12589              positive           neutral           positive
# 12655              positive           neutral           positive
# 12777               neutral          positive            neutral
# 12872              positive           neutral            neutral
# 13043               neutral          negative            neutral
# 13245              positive           neutral            neutral
# 13565               neutral          positive           positive
#
#       sentiment_staff sentiment_facility sentiment_value sentiment_room  \
# 0                 NaN           negative             NaN       negative
# 1             neutral            neutral         neutral        neutral
# 2                 NaN                NaN             NaN            NaN
# 3            positive                NaN             NaN            NaN
# 5                 NaN                NaN             NaN            NaN
# 11                NaN                NaN             NaN            NaN
# 12           positive                NaN             NaN            NaN
# 26                NaN           positive             NaN            NaN
# 45           positive           negative             NaN            NaN
# 55                NaN                NaN             NaN            NaN
# 9755          neutral            neutral         neutral       positive
# 9818         positive           positive         neutral       positive
# 10111         neutral            neutral         neutral        neutral
# 10280         neutral           positive         neutral       positive
# 10346        positive           positive         neutral        neutral
# 10757        positive            neutral         neutral        neutral
# 11413         neutral            neutral         neutral       positive
# 11572        positive            neutral         neutral       positive
# 11574        positive            neutral         neutral        neutral
# 11648         neutral            neutral         neutral        neutral
# 11802        positive            neutral         neutral       positive
# 11904         neutral            neutral         neutral        neutral
# 11972        positive            neutral         neutral       positive
# 12026         neutral           positive         neutral        neutral
# 12079         neutral            neutral         neutral        neutral
# 12126        positive            neutral         neutral        neutral
# 12136        positive            neutral         neutral       positive
# 12153        positive            neutral         neutral        neutral
# 12238         neutral            neutral         neutral        neutral
# 12246        positive            neutral         neutral        neutral
# 12303        positive            neutral         neutral       positive
# 12589        positive            neutral         neutral       positive
# 12655         neutral            neutral         neutral        neutral
# 12777        positive            neutral         neutral       positive
# 12872         neutral            neutral         neutral        neutral
# 13043         neutral            neutral         neutral        neutral
# 13245         neutral            neutral         neutral       positive
# 13565        positive            neutral        positive        neutral
#
#       sentiment_quality
# 0                   NaN
# 1               neutral
# 2                   NaN
# 3                   NaN
# 5                   NaN
# 11                  NaN
# 12                  NaN
# 26             positive
# 45                  NaN
# 55             positive
# 9755            neutral
# 9818            neutral
# 10111           neutral
# 10280           neutral
# 10346           neutral
# 10757           neutral
# 11413           neutral
# 11572           neutral
# 11574           neutral
# 11648           neutral
# 11802           neutral
# 11904           neutral
# 11972           neutral
# 12026           neutral
# 12079           neutral
# 12126           neutral
# 12136           neutral
# 12153           neutral
# 12238           neutral
# 12246           neutral
# 12303           neutral
# 12589           neutral
# 12655           neutral
# 12777           neutral
# 12872           neutral
# 13043           neutral
# 13245           neutral
# 13565           neutral

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import pandas as pd
import numpy as np

# %%
# 1. Distribusi Sentimen Umum
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='sentiment_general', order=df['sentiment_general'].value_counts().index, palette='viridis')
plt.title('Distribusi Sentimen Umum')
plt.xlabel('Sentimen')
plt.ylabel('Jumlah Ulasan')
plt.show()
# Out:
# <ipython-input-29-d5d597b58213>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='sentiment_general', order=df['sentiment_general'].value_counts().index, palette='viridis')

# %%
# 2. Distribusi Sentimen per Aspek
sentiment_columns = ['sentiment_meal', 'sentiment_surrounding', 'sentiment_service',
                     'sentiment_location', 'sentiment_staff', 'sentiment_facility',
                     'sentiment_value', 'sentiment_room']

plt.figure(figsize=(12, 6))
sentiment_counts = df[sentiment_columns].apply(pd.Series.value_counts).fillna(0)
sentiment_counts.T.plot(kind='bar', stacked=True, figsize=(12,6), colormap='viridis')
plt.title('Distribusi Sentimen Berdasarkan Aspek')
plt.xlabel('Aspek')
plt.ylabel('Jumlah Ulasan')
plt.xticks(rotation=45)
plt.legend(title='Sentimen')
plt.show()

# %%
# 3. Perbandingan Rating dengan Sentimen
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='sentiment_general', y='rating', palette='coolwarm')
plt.title('Distribusi Rating berdasarkan Sentimen')
plt.xlabel('Sentimen')
plt.ylabel('Rating')
plt.show()
# Out:
# <ipython-input-57-7d048b1fbef6>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='sentiment_general', y='rating', palette='coolwarm')

# %%
# Filter data: rating tinggi (>= 8) tetapi sentimen negatif pada aspek mana pun
high_rating_negative_sentiment = df[
    (df["rating"] >= 7) & (
        (df["sentiment_meal"] == "negative") |
        (df["sentiment_surrounding"] == "negative") |
        (df["sentiment_service"] == "negative") |
        (df["sentiment_location"] == "negative") |
        (df["sentiment_staff"] == "negative") |
        (df["sentiment_facility"] == "negative") |
        (df["sentiment_value"] == "negative") |
        (df["sentiment_room"] == "negative") |
        (df["sentiment_quality"] == "negative")
    )
]

# %%
df[
    df["rating"] >= 7
]
# Out:
#                                           review_message       source  \
# 0      Kamar bersih, ac dingin, air panas tdk konsist...       google
# 1      "I always stay at Horison Sukabumi Hotel when ...  tripadvisor
# 2      Bagus sekali, pengalaman pertama kali menginap...  tripadvisor
# 3      Kamarnya nya sangat bersih dan pelayanan nya j...  tripadvisor
# 4      Sudah langganan disini,,terimakasih agoda akan...        agoda
# ...                                                  ...          ...
# 19507  Secara umum saya nyaman nginap 3 malam disini ...  tripadvisor
# 19596  Kamar sangat bersih, bed nya nyaman kelas bint...        agoda
# 19610  booking dengan request minta kamar yg ac nya d...        tiket
# 19778  tidak sesuai request dan perlengkapan kurang p...        agoda
# 19936  Ac kurang dingin, sarapan kurang. Tempat nyama...        tiket
#
#          language sentiment_general  rating  sentiment_meal  \
# 0      Indonesian               NaN     8.0             NaN
# 1         English               NaN    10.0             NaN
# 2      Indonesian               NaN    10.0             NaN
# 3      Indonesian               NaN    10.0             NaN
# 4      Indonesian           Neutral    10.0             NaN
# ...           ...               ...     ...             ...
# 19507  Indonesian          Negative     8.0             NaN
# 19596  Indonesian          Negative     8.8             NaN
# 19610  Indonesian          Negative     8.8             NaN
# 19778  Indonesian          Negative     7.6             NaN
# 19936  Indonesian          Negative     8.0             NaN
#
#        sentiment_surrounding  sentiment_service  sentiment_location  \
# 0                        NaN                NaN                 NaN
# 1                        NaN                NaN                 NaN
# 2                        NaN                NaN                 NaN
# 3                        NaN                NaN                 NaN
# 4                        NaN                NaN                 NaN
# ...                      ...                ...                 ...
# 19507                    NaN                NaN                 NaN
# 19596                    NaN                NaN                 NaN
# 19610                    NaN                NaN                 NaN
# 19778                    NaN                NaN                 NaN
# 19936                    NaN                NaN                 NaN
#
#        sentiment_staff  sentiment_facility  sentiment_value  sentiment_room  \
# 0                  NaN                 NaN              NaN             NaN
# 1                  NaN                 NaN              NaN             NaN
# 2                  NaN                 NaN              NaN             NaN
# 3                  NaN                 NaN              NaN             NaN
# 4                  NaN                 NaN              NaN             NaN
# ...                ...                 ...              ...             ...
# 19507              NaN                 NaN              NaN             NaN
# 19596              NaN                 NaN              NaN             NaN
# 19610              NaN                 NaN              NaN             NaN
# 19778              NaN                 NaN              NaN             NaN
# 19936              NaN                 NaN              NaN             NaN
#
#        sentiment_quality
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 19507                NaN
# 19596                NaN
# 19610                NaN
# 19778                NaN
# 19936                NaN
#
# [14466 rows x 14 columns]

# %%
# 4. Perbandingan Sentimen Berdasarkan Platform (OTA)
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='source', hue='sentiment_general', order=df['source'].value_counts().index, palette='viridis')
plt.title('Perbandingan Sentimen Berdasarkan Platform (OTA)')
plt.xlabel('Platform')
plt.ylabel('Jumlah Ulasan')
plt.xticks(rotation=45)
plt.legend(title='Sentimen')
plt.show()

# %%
# 6. Word Cloud untuk Review Positif & Negatif
positive_text = " ".join(review for review in df[df['sentiment_general'] == 'Positive']['review_message'].dropna())
negative_text = " ".join(review for review in df[df['sentiment_general'] == 'Negative']['review_message'].dropna())

# %%
positive_text
# Out:
# 'Bagus dan nyaman sekali, staff nya ramah terimakasih horison Ciledug, hari ini aku bukber dihotel horison sama keluarga, menu untuk hari ini enak enak banget, apalagi nasi briani nya suka banget, untuk area restorant nya luas sekali dan aesthetic, instagramable banget, saya suka bukber di sini, mantapppp Service yang sangat memuaskan, staf sangat melayani dengan baik, kamar sangat bersih Pelayanan yang diberikan sudah bangus dan sangat baik, dimulai dengan staff yang ramah saat menyambut tamu. Untuk makanan sudah cukup enak dan melayani dengan cukup baik Untuk tempatnya sudah cukup bagus,bersih,dan sangat nyaman untuk istirahat Horison Nindya sangat rekomendasi untuk tempat menginap dan istirahat. Terimakasih mbak shinta f&b service atas pelayanan yang diberikan tidak pernahh bosaan untuk staycation disini karna sangat nyaman sekali menginap di horison ini,,, untuk pelayanan nya sangat ramah.. tempat nya sangat strategiss kemana manaa,, makanan nya juga sangat enakk enak sekali sangat rekomen untuk staycation bareng keluarga atau teman pertama kali menginap di horison ciledug,, menurut saya kamar nya sangat bersih dan wangi, pelayanan nya sangat cepaaat.. interior dari masuk lobby sampai ke kamar pun sangat baguss.. registrasi pada saat checkin juga cepaat,, staff nya sangat ramah goodd horison Pelayanan hotel ini sangat ramah sekali. Lobby juga harum dan bersih. Proses check out juga sangat cepat. Ada kolam renang anak dan gym area juga. Sangat rekomendasi sekali menginap disini. Akan kembali lagi dilain kesempatan. The bestt Comfortable, strategic location, spacious room, clean, I often go to Horison when visiting a city that has a horizon, from there to the MRT station is not far, Gambir is close, there are many travel options, keep it up! Pelayanan bagus, memuaskan, check in cepat. Kamar luas, bersih, smoking room dengan fasilitas yang komplit! Bednya besar, kamar mandi luas. Di hotel ada gym, kolam renang, restauran, dll. Teruntuk Mbak Diani terimakasih atas pelayanannya dan dibuatkan kopi. Fast check in. Friendly and helpful staff. Clean room. Clean bed and comfortable. Bathroom is ok. 5 mins walk to Simpang Lima. 2 mins walk to Cititrans pool. Many restaurants and food street near hotel. It\'s easy to order online transport. Highly recommended to stay at @Hom Semarang hotel. Keep it up. Clean rooms and friendly staff, the hotel is okay - view nya bagus - makanannya enak semua - pelayanan sangat cepat - para karyawan sangat sigap dan ramah - kamar yang bersih dan rapih fasilitas lengkap - kami sangat di bantu dgn karyawannya - cara memesan kamar nya mudah - harga nya worth itt saya menginap di kamar 649 menurut saya overall pelayanan sudah oke, proses check-in dan checkout sangat cepat dibantu oleh kak Ikbal, saya merasa nyaman stay disini, harganya pun sesuai lah dengan budget saya, terimakasih horison kotaraja sangat mantap , pengalaman pertama ke balikpapan menginap disini. pelayanan yng baik kamar luas area parkir kendaraan luas dan resto langsung menghadap landasan udara................................................................ Pelayanan ramah, kebersihan kamar baik, menu sarapan banyak pilihan. Masukan : tolong sediakan sendal.😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😁😆😆😆😆😆😆😆😆😆😆 Mantabs service hotel nya, semua pegawainya memberikan pelayanan yg memuaskan, makanan nya enak2, kamarnya bersih Dan rapih Mantabs service hotel nya, semua pegawainya memberikan pelayanan yg memuaskan, makanan nya enak2, kamarnya bersih Dan rapih Suspect price, spacious and comfortable room. Recommended. makanan berbukanya enak bangett suasana hotelnya juga nyaman banget walaupun rame ttp nyaman bersih dan seru banget bisa birthday juga dsni mba mbanya seru seru bangett dan cantik cantik,walaupun rame seru bangett tahun depan bukber dsni lagi🌹 ikut buka puasa dihorison ciledug dengan makanan yang banyak dan enak enak bangett,pelayanan yang baik baik bangett,diantar sm karyawananya sampai kekursin,dilayanain dengan baik dan hang ...

# %%
# Word Cloud Positif
plt.figure(figsize=(10, 5))
wordcloud_pos = WordCloud(width=800, height=400, background_color='white').generate(positive_text)
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis("off")
plt.title('Word Cloud - Review Positif')
plt.show()

# %%
# Word Cloud Positif
plt.figure(figsize=(10, 5))
wordcloud_pos = WordCloud(width=800, height=400, background_color='white').generate(positive_text)
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis("off")
plt.title('Word Cloud - Review Positif')
plt.show()

# %%
# Word Cloud Negatif
plt.figure(figsize=(10, 5))
wordcloud_neg = WordCloud(width=800, height=400, background_color='black', colormap='Reds').generate(negative_text)
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis("off")
plt.title('Word Cloud - Review Negatif')
plt.show()

# %%
# 7. Korelasi Antar Aspek Sentimen
sentiment_numeric = df[sentiment_columns].apply(lambda x: pd.factorize(x)[0])  # Mengubah kategori ke numerik
plt.figure(figsize=(10, 8))
sns.heatmap(sentiment_numeric.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Korelasi Antar Aspek Sentimen')
plt.show()

# %%
# Mapping nilai sentimen ke angka
sentiment_mapping = {"positive": 1, "neutral": 0, "negative": -1}

# Konversi nilai sentimen ke angka
for col in sentiment_columns:
    df[col] = df[col].map(sentiment_mapping)

# Hitung korelasi dengan rating
correlation_matrix = df[["rating"] + sentiment_columns].corr()
# Out:
# <ipython-input-52-a52c22799518>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(sentiment_mapping)
# <ipython-input-52-a52c22799518>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(sentiment_mapping)
# <ipython-input-52-a52c22799518>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(sentiment_mapping)
# <ipython-input-52-a52c22799518>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(sentiment_mapping)
# <ipython-input-52-a52c22799518>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(sentiment_mapping)
# <ipython-input-52-a52c22799518>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(sentiment_mapping)
# <ipython-input-52-a52c22799518>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(sentiment_mapping)
# <ipython-input-52-a52c22799518>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(sentiment_mapping)
# <ipython-input-52-a52c22799518>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(sentiment_mapping)

# %%
correlation_matrix
# Out:
#                          rating  sentiment_meal  sentiment_surrounding  \
# rating                 1.000000             NaN                    NaN
# sentiment_meal              NaN             NaN                    NaN
# sentiment_surrounding       NaN             NaN                    NaN
# sentiment_service           NaN             NaN                    NaN
# sentiment_location          NaN             NaN                    NaN
# sentiment_staff             NaN             NaN                    NaN
# sentiment_facility          NaN             NaN                    NaN
# sentiment_value             NaN             NaN                    NaN
# sentiment_room              NaN             NaN                    NaN
# sentiment_quality      0.414922             NaN                    NaN
#
#                        sentiment_service  sentiment_location  sentiment_staff  \
# rating                               NaN                 NaN              NaN
# sentiment_meal                       NaN                 NaN              NaN
# sentiment_surrounding                NaN                 NaN              NaN
# sentiment_service                    NaN                 NaN              NaN
# sentiment_location                   NaN                 NaN              NaN
# sentiment_staff                      NaN                 NaN              NaN
# sentiment_facility                   NaN                 NaN              NaN
# sentiment_value                      NaN                 NaN              NaN
# sentiment_room                       NaN                 NaN              NaN
# sentiment_quality                    NaN                 NaN              NaN
#
#                        sentiment_facility  sentiment_value  sentiment_room  \
# rating                                NaN              NaN             NaN
# sentiment_meal                        NaN              NaN             NaN
# sentiment_surrounding                 NaN              NaN             NaN
# sentiment_service                     NaN              NaN             NaN
# sentiment_location                    NaN              NaN             NaN
# sentiment_staff                       NaN              NaN             NaN
# sentiment_facility                    NaN              NaN             NaN
# sentiment_value                       NaN              NaN             NaN
# sentiment_room                        NaN              NaN             NaN
# sentiment_quality                     NaN              NaN             NaN
#
#                        sentiment_quality
# rating                          0.414922
# sentiment_meal                       NaN
# sentiment_surrounding                NaN
# sentiment_service                    NaN
# sentiment_location                   NaN
# sentiment_staff                      NaN
# sentiment_facility                   NaN
# sentiment_value                      NaN
# sentiment_room                       NaN
# sentiment_quality               1.000000

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

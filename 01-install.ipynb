# %%
# !pip install "elasticsearch<8.0.0"

# %%
from elasticsearch import Elasticsearch

# Konfigurasi koneksi ke Elasticsearch
ELASTICSEARCH_HOST = "http://es.robota.datains.id:80"  # Ganti dengan host Elasticsearch Anda
INDEX_NAME = "hotel_reviews"  # Ganti dengan nama indeks yang ingin diambil datanya

# Inisialisasi koneksi ke Elasticsearch
es = Elasticsearch([ELASTICSEARCH_HOST])


def get_large_data_from_elasticsearch(index, size=10000):
    """
    Mengambil data hingga 10.000 dokumen dari Elasticsearch dengan metode search_after.

    :param index: Nama indeks Elasticsearch.
    :param size: Jumlah maksimum data yang ingin diambil.
    :return: List hasil pencarian.
    """
    query = {
        "query": {
            "bool": {
                "should": [
                    {
                        "match": {
                            "review.language": "English"
                        }
                        },
                    {
                        "match": {
                            "review.language": "Indonesian"
                        }
                    }
                ],
                "must_not": [
                    {"match": { "sentiment_general": "Negative"}},
                ],
                "must": [
                    {"exists": {"field": "review.message"}},
                    {"exists": {"field": "sentiment"}},
                    {
                        "range": {
                            "review.date": {
                                "gte": "2020-01-22",
                                "lte": "now"
                            }
                        }
                    }
                ],
                "minimum_should_match": 1
            }
        },
        "sort": [
            {"review.date": {"order": "desc"}},
            {"_id": "asc"}  # Tambahkan _id untuk search_after
        ],
        "_source": ["source", "review", "sentiment", "sentiment_general"],
        "size": 1000  # Ambil data dalam batch 1000 per iterasi
    }

    results = []
    last_hit = None

    while len(results) < size:
        if last_hit:
            query["search_after"] = last_hit

        response = es.search(index=index, body=query)
        hits = response.get("hits", {}).get("hits", [])

        if not hits:
            break  # Jika tidak ada data lagi, berhenti

        results.extend(hits)

        # Set `search_after` berdasarkan dokumen terakhir
        last_hit = hits[-1]["sort"]

        # Jika sudah mencapai 10.000 data, berhenti
        if len(results) >= size:
            break

    return results[:size]  # Pastikan hanya 10.000 data yang dikembalikan


def get_large_negative_data_from_elasticsearch(index, size=10000):
    """
    Mengambil data hingga 10.000 dokumen dari Elasticsearch dengan metode search_after.

    :param index: Nama indeks Elasticsearch.
    :param size: Jumlah maksimum data yang ingin diambil.
    :return: List hasil pencarian.
    """
    query = {
        "query": {
            "bool": {
                "should": [
                    {
                        "match": {
                            "review.language": "English"
                        }
                    },
                    {
                        "match": {
                            "review.language": "Indonesian"
                        }
                    }
                ],
                "must": [
                    {"match": { "sentiment_general": "Negative"}},
                    {"exists": {"field": "review.message"}},
                    {"exists": {"field": "sentiment"}},
                    {
                        "range": {
                            "review.date": {
                                "gte": "2020-01-22",
                                "lte": "now"
                            }
                        }
                    }
                ],
                "minimum_should_match": 1
            }
        },
        "sort": [
            {"review.date": {"order": "desc"}},
            {"_id": "asc"}  # Tambahkan _id untuk search_after
        ],
        "_source": ["source", "review", "sentiment", "sentiment_general"],
        "size": 1000  # Ambil data dalam batch 1000 per iterasi
    }

    results = []
    last_hit = None

    while len(results) < size:
        if last_hit:
            query["search_after"] = last_hit

        response = es.search(index=index, body=query)
        hits = response.get("hits", {}).get("hits", [])

        if not hits:
            break  # Jika tidak ada data lagi, berhenti

        results.extend(hits)

        # Set `search_after` berdasarkan dokumen terakhir
        last_hit = hits[-1]["sort"]

        # Jika sudah mencapai 10.000 data, berhenti
        if len(results) >= size:
            break

    return results[:size]  # Pastikan hanya 10.000 data yang dikembalikan


def get_large_spesific_aspec(index, aspect="location", sentiment="negative", size=10000):
    """
    Mengambil data hingga 10.000 dokumen dari Elasticsearch dengan metode search_after.

    :param index: Nama indeks Elasticsearch.
    :param size: Jumlah maksimum data yang ingin diambil.
    :return: List hasil pencarian.
    """
    query = {
        "query": {
            "bool": {
                "should": [
                    {
                        "match": {
                            "review.language": "English"
                        }
                    },
                    {
                        "match": {
                            "review.language": "Indonesian"
                        }
                    }
                ],
                "must": [
                    {"match": { f"sentiment.{aspect}": sentiment}},
                    {"exists": {"field": "review.message"}},
                    {"exists": {"field": "sentiment"}}
                ],
                "minimum_should_match": 1
            }
        },
        "sort": [
            {"review.date": {"order": "desc"}},
            {"_id": "asc"}  # Tambahkan _id untuk search_after
        ],
        "_source": ["source", "review", "sentiment", "sentiment_general"],
        "size": 1000  # Ambil data dalam batch 1000 per iterasi
    }

    results = []
    last_hit = None

    while len(results) < size:
        if last_hit:
            query["search_after"] = last_hit

        response = es.search(index=index, body=query)
        hits = response.get("hits", {}).get("hits", [])

        if not hits:
            break  # Jika tidak ada data lagi, berhenti

        results.extend(hits)

        # Set `search_after` berdasarkan dokumen terakhir
        last_hit = hits[-1]["sort"]

        # Jika sudah mencapai 10.000 data, berhenti
        if len(results) >= size:
            break

    return results[:size]  # Pastikan hanya 10.000 data yang dikembalikan

# %%
import json
import pandas as pd

# Fungsi untuk mengonversi JSON Elasticsearch ke CSV
def convert_json_to_df(data):
    """
    Mengonversi file JSON hasil Elasticsearch ke CSV dengan hanya mengambil
    review.message, language.language, sentiment.*, dan sentiment_general.

    :param json_file: Path file JSON input.
    :param csv_file: Path file CSV output.
    """
    # Pastikan data dalam format Elasticsearch (_source)
    records = []
    for record in data:  # Ambil dari _source
        source = record["_source"]
        row = {
            "review_message": source.get("review", {}).get("message", ""),
            "source": source.get("source", None),
            "language": source.get("review", {}).get("language", ""),
            "sentiment_general": source.get("sentiment_general", ""),
            "rating": source.get("review", {}).get("rating_normalization", {}).get("normal", None)
        }

        # Ambil semua sentiment.*
        for key, value in source.get("sentiment", {}).items():
            row[f"sentiment_{key}"] = value

        records.append(row)

    # Konversi ke DataFrame
    df = pd.DataFrame(records)
    return df

# %%
# Query untuk mengambil semua data
results_no_negative = get_large_data_from_elasticsearch(INDEX_NAME, size=15000)
results_negative = get_large_negative_data_from_elasticsearch(INDEX_NAME, size=5000)
# Out:
# <ipython-input-2-84815c1d166d>:67: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   response = es.search(index=index, body=query)
# <ipython-input-2-84815c1d166d>:139: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   response = es.search(index=index, body=query)

# %%
# Contoh penggunaan

df_no_negative = convert_json_to_df(results_no_negative)
df_negative = convert_json_to_df(results_negative)

df = pd.concat([df_no_negative, df_negative], ignore_index=True)

# %%
df.head()
# Out:
#                                       review_message       source    language  \
# 0         Good location, only few minutes to airport    traveloka     English
# 1  Semacam glamping di pinggir sungai, untuk temp...       google  Indonesian
# 2  Makanan dan minuman di iftar bukber enak pelay...  tripadvisor  Indonesian
# 3  Pertama kali masuk ke lobi di sambut dengan ba...  tripadvisor  Indonesian
# 4  berbuka puasa di horison Ciledug bareng keluar...  tripadvisor  Indonesian
#
#   sentiment_general  rating sentiment_meal sentiment_surrounding  \
# 0                       9.4        neutral              positive
# 1                       8.0
# 2                      10.0       positive
# 3                      10.0       positive
# 4                      10.0       positive
#
#   sentiment_service sentiment_location sentiment_staff sentiment_facility  \
# 0           neutral           positive         neutral            neutral
# 1
# ...

# %%
import pandas as pd
import numpy as np

# Mengganti semua nilai "" menjadi NaN
df.replace("", np.nan, inplace=True)

# Menampilkan jumlah nilai NaN setelah pembersihan
print(df.isna().sum())
# Out:
# review_message             37
# source                      0
# language                    0
# sentiment_general          54
# rating                      0
# sentiment_meal           5915
# sentiment_surrounding    8364
# sentiment_service        4667
# sentiment_location       7717
# sentiment_staff          5150
# sentiment_facility       5692
# sentiment_value          8468
# sentiment_room           3914
# sentiment_quality        4335
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   review_message         19963 non-null  object
#  1   source                 20000 non-null  object
#  2   language               20000 non-null  object
#  3   sentiment_general      19946 non-null  object
#  4   rating                 20000 non-null  float64
#  5   sentiment_meal         14085 non-null  object
#  6   sentiment_surrounding  11636 non-null  object
#  7   sentiment_service      15333 non-null  object
#  8   sentiment_location     12283 non-null  object
#  9   sentiment_staff        14850 non-null  object
#  10  sentiment_facility     14308 non-null  object
#  11  sentiment_value        11532 non-null  object
#  12  sentiment_room         16086 non-null  object
#  13  sentiment_quality      15665 non-null  object
# dtypes: float64(1), object(13)
# ...

# %%
df.isnull().sum()
# Out:
# review_message             37
# source                      0
# language                    0
# sentiment_general          54
# rating                      0
# sentiment_meal           5915
# sentiment_surrounding    8364
# sentiment_service        4667
# sentiment_location       7717
# sentiment_staff          5150
# sentiment_facility       5692
# sentiment_value          8468
# sentiment_room           3914
# sentiment_quality        4335
# dtype: int64

# %%
df = df.dropna(subset=["review_message"])

# %%
df.isnull().sum()
# Out:
# review_message              0
# source                      0
# language                    0
# sentiment_general          53
# rating                      0
# sentiment_meal           5886
# sentiment_surrounding    8335
# sentiment_service        4638
# sentiment_location       7688
# sentiment_staff          5125
# sentiment_facility       5663
# sentiment_value          8439
# sentiment_room           3886
# sentiment_quality        4309
# dtype: int64

# %% [markdown]
# ## Evaluasi dataset awal

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import pandas as pd
import numpy as np

# %%
# 1. Distribusi Sentimen Umum
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='sentiment_general', order=df['sentiment_general'].value_counts().index, palette='viridis')
plt.title('Distribusi Sentimen Umum')
plt.xlabel('Sentimen')
plt.ylabel('Jumlah Ulasan')
plt.show()
# Out:
# <ipython-input-123-d5d597b58213>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='sentiment_general', order=df['sentiment_general'].value_counts().index, palette='viridis')

# %%
df['language'].value_counts().index
# Out:
# Index(['English', 'Indonesian', 'English (United States)', 'English (Canada)',
#        'English (United Kingdom)', 'English (Singapore)',
#        'English (Australia)', 'English (Hong Kong SAR China)'],
#       dtype='object', name='language')

# %%
# Normalisasi semua varian "English*" menjadi "English"
df["language"] = df["language"].replace(to_replace=r"English.*", value="English", regex=True)

# Cek hasil setelah normalisasi
print(df["language"].value_counts())
# Out:
# language
# English       11090
# Indonesian     8873
# Name: count, dtype: int64

# %%
df['language'].value_counts().index
# Out:
# Index(['English', 'Indonesian'], dtype='object', name='language')

# %%
# 1. Distribusi Sentimen Umum
plt.figure(figsize=(8, 5))
sns.countplot(
    data=df,
    x='language',
    order=df['language'].value_counts().index,
    palette='viridis'
)
plt.title('Distribusi Sentimen Umum')
plt.xlabel('Sentimen')
plt.ylabel('Jumlah Ulasan')
plt.show()
# Out:
# <ipython-input-127-dd60e362492c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
# 2. Distribusi Sentimen per Aspek
sentiment_columns = ['sentiment_meal', 'sentiment_surrounding', 'sentiment_service',
                     'sentiment_location', 'sentiment_staff', 'sentiment_facility',
                     'sentiment_value', 'sentiment_room']

plt.figure(figsize=(12, 6))
sentiment_counts = df[sentiment_columns].apply(pd.Series.value_counts).fillna(0)
sentiment_counts.T.plot(kind='bar', stacked=True, figsize=(12,6), colormap='viridis')
plt.title('Distribusi Sentimen Berdasarkan Aspek')
plt.xlabel('Aspek')
plt.ylabel('Jumlah Ulasan')
plt.xticks(rotation=45)
plt.legend(title='Sentimen')
plt.show()

# %%
df_meal_negative = get_large_spesific_aspec(INDEX_NAME, aspect="meal", sentiment="negative", size=1000)
df_location_negative = get_large_spesific_aspec(INDEX_NAME, aspect="location", sentiment="negative", size=1000)
df_value_negative = get_large_spesific_aspec(INDEX_NAME, aspect="value", sentiment="negative", size=1000)
# Out:
# <ipython-input-2-84815c1d166d>:203: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   response = es.search(index=index, body=query)

# %%
df_meal_negative = convert_json_to_df(df_meal_negative)
df_location_negative = convert_json_to_df(df_location_negative)
df_value_negative = convert_json_to_df(df_value_negative)

# %%
# Gabungkan DataFrame
df = pd.concat([df, df_meal_negative, df_location_negative, df_value_negative], ignore_index=True)

# %%
df.shape
# Out:
# (22515, 14)

# %% [markdown]
# ## Evaluasi hasil penambahan dataset

# %%
import pandas as pd
import numpy as np

# Mengganti semua nilai "" menjadi NaN
df.replace("", np.nan, inplace=True)

# Menampilkan jumlah nilai NaN setelah pembersihan
print(df.isna().sum())
# Out:
# review_message               0
# source                       0
# language                     0
# sentiment_general           58
# rating                       0
# sentiment_meal            6618
# sentiment_surrounding    10181
# sentiment_service         6251
# sentiment_location        9035
# sentiment_staff           6739
# sentiment_facility        7089
# sentiment_value           9881
# sentiment_room            4977
# sentiment_quality         5745
# dtype: int64

# %%
# 1. Distribusi Sentimen Umum
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='sentiment_general', order=df['sentiment_general'].value_counts().index, palette='viridis')
plt.title('Distribusi Sentimen Umum')
plt.xlabel('Sentimen')
plt.ylabel('Jumlah Ulasan')
plt.show()
# Out:
# <ipython-input-134-d5d597b58213>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='sentiment_general', order=df['sentiment_general'].value_counts().index, palette='viridis')

# %%
df['language'].value_counts().index
# Out:
# Index(['English', 'Indonesian', 'English (United States)',
#        'English (United Kingdom)', 'English (Australia)',
#        'Indonesian (Indonesia)', 'English (Canada)', 'English (Singapore)'],
#       dtype='object', name='language')

# %%
# Normalisasi semua varian "English*" menjadi "English"
df["language"] = df["language"].replace(to_replace=r"English.*", value="English", regex=True)
df["language"] = df["language"].replace(to_replace=f"Indonesian.*", value="Indonesian", regex=True)

# Cek hasil setelah normalisasi
print(df["language"].value_counts())
# Out:
# language
# English       11587
# Indonesian    10928
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                       review_message       source    language  \
# 0         Good location, only few minutes to airport    traveloka     English
# 1  Semacam glamping di pinggir sungai, untuk temp...       google  Indonesian
# 2  Makanan dan minuman di iftar bukber enak pelay...  tripadvisor  Indonesian
# 3  Pertama kali masuk ke lobi di sambut dengan ba...  tripadvisor  Indonesian
# 4  berbuka puasa di horison Ciledug bareng keluar...  tripadvisor  Indonesian
#
#   sentiment_general  rating sentiment_meal sentiment_surrounding  \
# 0               NaN     9.4        neutral              positive
# 1               NaN     8.0            NaN                   NaN
# 2               NaN    10.0       positive                   NaN
# 3               NaN    10.0       positive                   NaN
# 4               NaN    10.0       positive                   NaN
#
#   sentiment_service sentiment_location sentiment_staff sentiment_facility  \
# ...

# %%
# Convert 'jadi' to lowercase in 'language' and 'general_sentiment' columns
df["language"] = df["language"].str.lower()
df["sentiment_general"] = df["sentiment_general"].str.lower()

# %%
df.tail()
# Out:
#                                           review_message       source  \
# 22510  I don't think pop management try to consider h...  tripadvisor
# 22511  It's one of the most expensive hotels on the i...  tripadvisor
# 22512  Hotel Bersih, makanan variatif. Pelayanan bagu...    traveloka
# 22513  A strategic hotel, near shopping and culinary ...    traveloka
# 22514  Cukup lengkap fasilitas yang diberikan dengan ...        tiket
#
#          language sentiment_general  rating sentiment_meal  \
# 22510     english           neutral     4.0        neutral
# 22511     english           neutral     2.0        neutral
# 22512  indonesian          positive     9.7       positive
# 22513     english           neutral     8.5            NaN
# 22514  indonesian           neutral     9.6            NaN
#
#       sentiment_surrounding sentiment_service sentiment_location  \
# 22510               neutral           neutral            neutral
# ...

# %%
# 1. Distribusi Sentimen Umum
plt.figure(figsize=(8, 5))
sns.countplot(
    data=df,
    x='language',
    order=df['language'].value_counts().index,
    palette='viridis'
)
plt.title('Distribusi Sentimen Umum')
plt.xlabel('Sentimen')
plt.ylabel('Jumlah Ulasan')
plt.show()
# Out:
# <ipython-input-141-dd60e362492c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
# Check for duplicate rows based on 'review_message' column
duplicate_rows = df[df.duplicated(subset=['review_message'], keep=False)]

# Print or analyze duplicate rows
print("Duplicate Rows:")
print(duplicate_rows)

# Remove duplicate rows, keeping the first occurrence
df_deduplicated = df.drop_duplicates(subset=['review_message'], keep='first')

# Print the shape of the original and deduplicated dataframes
print("\nOriginal DataFrame shape:", df.shape)
print("Deduplicated DataFrame shape:", df_deduplicated.shape)
# Out:
# Duplicate Rows:
#                                           review_message       source  \
# 12     Kamar bersih, ac dingin, air panas tdk konsist...       google
# 69     Lagi kecewa banget sama acara Buka Puasa di Ho...       google
# 78     Saya pribadi sih ga akan mau nginep lg di hote...       google
# 171                                     Sangat memuaskan       google
# 194    Untuk pelayanan hotel sudah bagus cuma kurang ...       google
# ...                                                  ...          ...
# 22482  The management confirmed they would provide me...  tripadvisor
# 22483  Roomnya sempit untuk harga yang mahal....kagak...  tripadvisor
# 22487  This is not a good hotel for your stay.  When ...      expedia
# 22496  The room was very dirty, had a very poor maint...      expedia
# 22507        Hahaha Wkwkwwk MAHAL... Ga sesuai ekspetasi        tiket
#
#          language sentiment_general  rating sentiment_meal  \
# ...

# %%
# 2. Distribusi Sentimen per Aspek
sentiment_columns = ['sentiment_meal', 'sentiment_surrounding', 'sentiment_service',
                     'sentiment_location', 'sentiment_staff', 'sentiment_facility',
                     'sentiment_value', 'sentiment_room']

plt.figure(figsize=(12, 6))
sentiment_counts = df[sentiment_columns].apply(pd.Series.value_counts).fillna(0)
sentiment_counts.T.plot(kind='bar', stacked=True, figsize=(12,6), colormap='viridis')
plt.title('Distribusi Sentimen Berdasarkan Aspek')
plt.xlabel('Aspek')
plt.ylabel('Jumlah Ulasan')
plt.xticks(rotation=45)
plt.legend(title='Sentimen')
plt.show()

# %%
# Get unique values from sentiment columns
sentiment_columns = ['sentiment_meal', 'sentiment_surrounding', 'sentiment_service',
                     'sentiment_location', 'sentiment_staff', 'sentiment_facility',
                     'sentiment_value', 'sentiment_room']

unique_sentiments = set()
for col in sentiment_columns:
    unique_sentiments.update(df[col].dropna().unique())

unique_sentiments
# Out:
# {'negative', 'neutral', 'positive'}

# %%
# Get unique values from sentiment columns
sentiment_columns = ['sentiment_general']

unique_sentiments = set()
for col in sentiment_columns:
    unique_sentiments.update(df[col].dropna().unique())

unique_sentiments
# Out:
# {'negative', 'neutral', 'positive'}

# %%
# Fill NaN values in sentiment columns with "Not Mentioned"
sentiment_columns = ['sentiment_meal', 'sentiment_surrounding', 'sentiment_service',
                     'sentiment_location', 'sentiment_staff', 'sentiment_facility',
                     'sentiment_value', 'sentiment_room', 'sentiment_quality']
for col in sentiment_columns:
    df[col].fillna("not mentioned", inplace=True)
# Out:
# <ipython-input-146-3fea6cd73209>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("not mentioned", inplace=True)

# %%
# Fill NaN values in 'sentiment_general' based on the mode of each aspect
for index, row in df.iterrows():
    if pd.isnull(row['sentiment_general']):
        aspect_sentiments = []
        for col in ['sentiment_meal', 'sentiment_surrounding', 'sentiment_service',
                    'sentiment_location', 'sentiment_staff', 'sentiment_facility',
                    'sentiment_value', 'sentiment_room', 'sentiment_quality']:
            aspect_sentiments.append(row[col])

        # Remove 'not mentioned' values before calculating the mode
        cleaned_sentiments = [s for s in aspect_sentiments if s != 'not mentioned']

        if cleaned_sentiments:
            mode_sentiment = max(set(cleaned_sentiments), key=cleaned_sentiments.count)
            df.loc[index, 'sentiment_general'] = mode_sentiment
        else:
            # If all aspects are 'not mentioned', fill with 'Neutral'
            # or another default value as needed
            df.loc[index, 'sentiment_general'] = 'neutral'

# %%
# 3. Perbandingan Rating dengan Sentimen
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='sentiment_general', y='rating', palette='coolwarm')
plt.title('Distribusi Rating berdasarkan Sentimen')
plt.xlabel('Sentimen')
plt.ylabel('Rating')
plt.show()
# Out:
# <ipython-input-149-7d048b1fbef6>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='sentiment_general', y='rating', palette='coolwarm')

# %%
df.shape
# Out:
# (22515, 14)

# %%
# 4. Perbandingan Sentimen Berdasarkan Platform (OTA)
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='source', hue='sentiment_general', order=df['source'].value_counts().index, palette='viridis')
plt.title('Perbandingan Sentimen Berdasarkan Platform (OTA)')
plt.xlabel('Platform')
plt.ylabel('Jumlah Ulasan')
plt.xticks(rotation=45)
plt.legend(title='Sentimen')
plt.show()

# %%
# 6. Word Cloud untuk Review Positif & Negatif
positive_text = " ".join(review for review in df[df['sentiment_general'] == 'positive']['review_message'].dropna())
negative_text = " ".join(review for review in df[df['sentiment_general'] == 'negative']['review_message'].dropna())

# %%
positive_text
# Out:
# 'Semacam glamping di pinggir sungai, untuk tempatnya bagus banget, dingin dan udaranya bersih. Cuma minusnya kurang bersih aja sih tempat tidurnya, service oke banget Makanan dan minuman di iftar bukber enak pelayanan ramah baik fasilitas hotel baik dan memadai untuk hotel horison Nindya ada taman nya bisa buat foto ataupun konten tempat resto bersih,bagus,nyaman, dan sangat nyaman untuk makan atau minum. Terima kasih staff FBS mas Adli atas pelayanan yang di berikan Pertama kali masuk ke lobi di sambut dengan baik oleh karyawan di depan dan langsung di arahkan ke greater , greater nya baik sopan dan ramah , makanan nya enak dan lengap varian nya banyak , untuk servis nya bagus , baik dan ramahh , saya senang berbuka di horison cileduk berbuka puasa di horison Ciledug bareng keluarga,makanannya enak enak bangettt, pelayanan nya juga baik staf nya ramah ramah,di antar sampai ke kursi sama staff nya, pelayanan nya juga sangat baik,rekomen bgt nih buat bukber bareng keluarga ataupun tem
# ...

# %%
# Word Cloud Positif
plt.figure(figsize=(10, 5))
wordcloud_pos = WordCloud(width=800, height=400, background_color='white').generate(positive_text)
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis("off")
plt.title('Word Cloud - Review Positif')
plt.show()

# %%
# Word Cloud Negatif
plt.figure(figsize=(10, 5))
wordcloud_neg = WordCloud(width=800, height=400, background_color='black', colormap='Reds').generate(negative_text)
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis("off")
plt.title('Word Cloud - Review Negatif')
plt.show()

# %%
# 7. Korelasi Antar Aspek Sentimen
sentiment_numeric = df[sentiment_columns].apply(lambda x: pd.factorize(x)[0])  # Mengubah kategori ke numerik
plt.figure(figsize=(10, 8))
sns.heatmap(sentiment_numeric.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Korelasi Antar Aspek Sentimen')
plt.show()

# %% [markdown]
# Heatmap korelasi antar aspek sentimen menunjukkan beberapa hubungan kuat yang menarik dalam ulasan hotel. **Sentiment room dan sentiment quality memiliki korelasi tertinggi (0.78)**, menunjukkan bahwa kualitas keseluruhan hotel sangat dipengaruhi oleh kondisi kamar. **Sentiment staff dan sentiment service juga berkorelasi cukup kuat (0.66)**, menandakan bahwa pengalaman pelayanan hotel sering kali ditentukan oleh interaksi dengan staf. Selain itu, **sentiment quality juga memiliki korelasi yang cukup tinggi dengan sentiment meal (0.57) dan sentiment value (0.53)**, yang mengindikasikan bahwa aspek makanan dan nilai harga yang diberikan turut mempengaruhi persepsi kualitas hotel secara keseluruhan.
#
# Sebaliknya, beberapa aspek menunjukkan korelasi negatif atau sangat lemah, seperti **sentiment location dengan sentiment quality (-0.46)** dan **sentiment meal dengan sentiment location (-0.35)**, yang menunjukkan bahwa persepsi terhadap lokasi hotel tidak selalu berhubungan dengan pengalaman terhadap makanan atau kualitas layanan. Selain itu, sentiment surrounding memiliki korelasi yang sangat rendah terhadap aspek lain, mengindikasikan bahwa faktor lingkungan sekitar hotel memiliki dampak yang lebih independen dibandingkan aspek lainnya. Secara keseluruhan, pola korelasi ini mengindikasikan bahwa kualitas kamar, layanan, dan fasilitas menjadi faktor utama yang menentukan pengalaman tamu, sementara lokasi dan lingkungan memiliki pengaruh yang lebih terpisah dalam pembentukan sentimen pelanggan.

# %%
import matplotlib.pyplot as plt

# Calculate character length for each comment
df['comment_length'] = df['review_message'].str.len()

# Group by comment length and count the frequency
comment_length_counts = df.groupby('comment_length').size().reset_index(name='frequency')


# Create the bar chart
plt.figure(figsize=(12, 6))
plt.bar(comment_length_counts['comment_length'], comment_length_counts['frequency'], color='skyblue')  # Set bar color
plt.xlabel('Comment Length (characters)')
plt.ylabel('Frequency')
plt.title('Frequency of Comments vs. Comment Length')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#                                       review_message       source    language  \
# 0         Good location, only few minutes to airport    traveloka     english
# 1  Semacam glamping di pinggir sungai, untuk temp...       google  indonesian
# 2  Makanan dan minuman di iftar bukber enak pelay...  tripadvisor  indonesian
# 3  Pertama kali masuk ke lobi di sambut dengan ba...  tripadvisor  indonesian
# 4  berbuka puasa di horison Ciledug bareng keluar...  tripadvisor  indonesian
#
#   sentiment_general  rating sentiment_meal sentiment_surrounding  \
# 0           neutral     9.4        neutral              positive
# 1          positive     8.0  not mentioned         not mentioned
# 2          positive    10.0       positive         not mentioned
# 3          positive    10.0       positive         not mentioned
# 4          positive    10.0       positive         not mentioned
#
#   sentiment_service sentiment_location sentiment_staff sentiment_facility  \
# ...

# %%
# Calculate the correlation between comment length and sentiment
correlation = df['comment_length'].corr(df['sentiment_general'].astype('category').cat.codes)

print(f"Correlation between comment length and sentiment: {correlation}")

# Label sentiment with numerical values for easier plotting
sentiment_mapping = {'negative': -1, 'positive': 1, 'neutral': 0, 'not mentioned': 0}  # Map sentiment to numbers
df['sentiment_numeric'] = df['sentiment_general'].map(sentiment_mapping)

# Plotting the relationship
plt.figure(figsize=(10, 6))
plt.scatter(df['comment_length'], df['sentiment_numeric'], alpha=0.5)  # Scatter plot with transparency for better visualization
plt.xlabel('Comment Length')
plt.ylabel('Sentiment (Numerical)')
plt.title('Comment Length vs. Sentiment')
plt.grid(True)


plt.show()
# Out:
# Correlation between comment length and sentiment: -0.2963187768652104

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()
# Out:
#                                       review_message       source    language  \
# 0         Good location, only few minutes to airport    traveloka     english
# 1  Semacam glamping di pinggir sungai, untuk temp...       google  indonesian
# 2  Makanan dan minuman di iftar bukber enak pelay...  tripadvisor  indonesian
# 3  Pertama kali masuk ke lobi di sambut dengan ba...  tripadvisor  indonesian
# 4  berbuka puasa di horison Ciledug bareng keluar...  tripadvisor  indonesian
#
#   sentiment_general  rating sentiment_meal sentiment_surrounding  \
# 0           neutral     9.4        neutral              positive
# 1          positive     8.0  not mentioned         not mentioned
# 2          positive    10.0       positive         not mentioned
# 3          positive    10.0       positive         not mentioned
# 4          positive    10.0       positive         not mentioned
#
#   sentiment_service sentiment_location sentiment_staff sentiment_facility  \
# ...

# %%
df.head()
# Out:
#                                       review_message       source    language  \
# 0         Good location, only few minutes to airport    traveloka     english
# 1  Semacam glamping di pinggir sungai, untuk temp...       google  indonesian
# 2  Makanan dan minuman di iftar bukber enak pelay...  tripadvisor  indonesian
# 3  Pertama kali masuk ke lobi di sambut dengan ba...  tripadvisor  indonesian
# 4  berbuka puasa di horison Ciledug bareng keluar...  tripadvisor  indonesian
#
#   sentiment_general  rating sentiment_meal sentiment_surrounding  \
# 0           neutral     9.4        neutral              positive
# 1          positive     8.0  not mentioned         not mentioned
# 2          positive    10.0       positive         not mentioned
# 3          positive    10.0       positive         not mentioned
# 4          positive    10.0       positive         not mentioned
#
#   sentiment_service sentiment_location sentiment_staff sentiment_facility  \
# ...

# %%
df.to_csv("/content/drive/MyDrive/dataset/labeled_hotel_reviews_normal.csv")
